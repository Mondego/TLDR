# %%
import pandas as pd
df = pd.read_csv('/Users/demigorgan/Documents/workspace/tldr/common-math.csv')

df
# Out:
#           Project                                    Commit  \
# 0    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 1    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 2    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 3    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 4    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 5    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 6    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 7    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 8    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 9    commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 10   commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 11   commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 12   commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 13   commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# 14   commons-math  f55f1566f0368842718c69de5c951d1642d2cb13
# ...

# %%
df.groupby(['Commit']).sum()
# Out:
#                                           Entity
# Commit
# 08042a0c22ab360a04fbe96c6bb8096f1560c2e6       5
# 177aef7abc521047e859b19f70cc6d98b680701d      15
# 1bd29782355ea38b460918d461c55a33a28b7e88      10
# 21a95478c2057bc6d2086a9e4904c0335ca72a03      22
# 2a4219105eb7abc98bc393ebae4422cbcad11b1e       1
# 32ea2a389ab8f2f8c5620498be82f1ae174e1b38      44
# 358973c257b58a5f4331820198cba0b4bc5a108a       0
# 35af6fe1d2d5eb648a4d15a3aeaf630064bd7e77      35
# 409d56d206891f76a3e751e4dcdcd22a8c898acc       2
# 4b1994a2ff9ee572271d0ed4fe54943330e23c1f     124
# 55b2cc8c039d659da8f4d8af332814043d084a3b       5
# 81310ec9a43c6b9cc8f72c87fbb5deec88273371     191
# 882493e7b1065b5898fc6bbb592f412317916dae       0
# 8b4803708042d3ddd4da64ad02462d8c4b7ee590      15
# 9b0466f648f08d51097acbc4068143b228c3f2b2       0
# 9ddf255a72a6d56e4d70d3c69eeff4ba98df253e      61
# 9f8370f33655e313fc48515b895be08d42870d1c       5
# a556284602c58312d962bace85018f5b6302d3f4       0
# ...
